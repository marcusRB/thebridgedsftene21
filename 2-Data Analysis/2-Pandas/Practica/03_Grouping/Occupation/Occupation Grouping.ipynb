# %% [markdown]
# # Occupation

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users.groupby(['occupation', 'gender']).count().reset_index()[['occupation', 'gender', 'age']]
# Out:
#        occupation gender  age
# 0   administrator      F   36
# 1   administrator      M   43
# 2          artist      F   13
# 3          artist      M   15
# 4          doctor      M    7
# 5        educator      F   26
# 6        educator      M   69
# 7        engineer      F    2
# 8        engineer      M   65
# 9   entertainment      F    2
# 10  entertainment      M   16
# 11      executive      F    3
# 12      executive      M   29
# 13     healthcare      F   11
# 14     healthcare      M    5
# 15      homemaker      F    6
# 16      homemaker      M    1
# 17         lawyer      F    2
# 18         lawyer      M   10
# 19      librarian      F   29
# 20      librarian      M   22
# 21      marketing      F   10
# 22      marketing      M   16
# 23           none      F    4
# 24           none      M    5
# 25          other      F   36
# 26          other      M   69
# 27     programmer      F    6
# 28     programmer      M   60
# 29        retired      F    1
# ...

# %%
users2 = users.groupby(['occupation', 'gender']).count()

users2 = users2.reset_index()[['occupation', 'gender', 'age']]
users2.rename(columns={'age': 'Conteo Occ'}, inplace=True)
users2
# Out:
#        occupation gender  Conteo Occ
# 0   administrator      F          36
# 1   administrator      M          43
# 2          artist      F          13
# 3          artist      M          15
# 4          doctor      M           7
# 5        educator      F          26
# 6        educator      M          69
# 7        engineer      F           2
# 8        engineer      M          65
# 9   entertainment      F           2
# 10  entertainment      M          16
# 11      executive      F           3
# 12      executive      M          29
# 13     healthcare      F          11
# 14     healthcare      M           5
# 15      homemaker      F           6
# 16      homemaker      M           1
# 17         lawyer      F           2
# 18         lawyer      M          10
# 19      librarian      F          29
# 20      librarian      M          22
# 21      marketing      F          10
# 22      marketing      M          16
# 23           none      F           4
# ...

# %%
def get_ratio(x):
    x['ratio'] = x['Conteo Occ']/x['Conteo Occ'].sum()
    
users2.groupby('occupation').apply(get_ratio)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Good one and easy
def norm_by_data2(x):
    x['ratio'] = x['age']*100/x['age'].sum()
    return x

users2 = users.groupby(['occupation', 'gender']).count()
users2.reset_index().groupby(['occupation']).apply(norm_by_data2)[['occupation', 'gender', 'ratio']]
# Out:
#        occupation gender       ratio
# 0   administrator      F   45.569620
# 1   administrator      M   54.430380
# 2          artist      F   46.428571
# 3          artist      M   53.571429
# 4          doctor      M  100.000000
# 5        educator      F   27.368421
# 6        educator      M   72.631579
# 7        engineer      F    2.985075
# 8        engineer      M   97.014925
# 9   entertainment      F   11.111111
# 10  entertainment      M   88.888889
# 11      executive      F    9.375000
# 12      executive      M   90.625000
# 13     healthcare      F   68.750000
# 14     healthcare      M   31.250000
# 15      homemaker      F   85.714286
# 16      homemaker      M   14.285714
# 17         lawyer      F   16.666667
# 18         lawyer      M   83.333333
# 19      librarian      F   56.862745
# 20      librarian      M   43.137255
# 21      marketing      F   38.461538
# 22      marketing      M   61.538462
# 23           none      F   44.444444
# ...

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation')['age'].agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).mean().reset_index()
# Out:
#        occupation gender        age
# 0   administrator      F  40.638889
# 1   administrator      M  37.162791
# 2          artist      F  30.307692
# 3          artist      M  32.333333
# 4          doctor      M  43.571429
# 5        educator      F  39.115385
# 6        educator      M  43.101449
# 7        engineer      F  29.500000
# 8        engineer      M  36.600000
# 9   entertainment      F  31.000000
# 10  entertainment      M  29.000000
# 11      executive      F  44.000000
# 12      executive      M  38.172414
# 13     healthcare      F  39.818182
# 14     healthcare      M  45.400000
# 15      homemaker      F  34.166667
# 16      homemaker      M  23.000000
# 17         lawyer      F  39.500000
# 18         lawyer      M  36.200000
# 19      librarian      F  40.000000
# 20      librarian      M  40.000000
# 21      marketing      F  37.200000
# 22      marketing      M  37.875000
# 23           none      F  36.500000
# 24           none      M  18.600000
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
# APARTADO 5
